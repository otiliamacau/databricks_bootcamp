# %%
# %sql
USE CATALOG workspace;

# %% [markdown]
# # Create Lakehouse Schema

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze
COMMENT 'Bronze layer: raw data';

CREATE SCHEMA IF NOT EXISTS silver
COMMENT 'Silver layer: cleanned and transformed data';

CREATE SCHEMA IF NOT EXISTS gold
COMMENT 'Gold layer: business-ready data';

# %% [markdown]
# # CREATE VOLUME

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.bronze.source_system
COMMENT 'Volume for raw source files';
