# %% [markdown]
# # Orchestration Logic
# This notebook programmatically runs all Silver transformation notebooks in sequence.
# It becomes the single entry point for the Silver layer in Databricks Jobs.

# %%
notebooks = [
  "/Workspace/Users/otilia.cecilia.lungu@gmail.com/databricks_bootcamp/bike_lakehouse/Silver/Silver_crm_cust_info",
  "/Workspace/Users/otilia.cecilia.lungu@gmail.com/databricks_bootcamp/bike_lakehouse/Silver/Silver_crm_prd_info",
  "/Workspace/Users/otilia.cecilia.lungu@gmail.com/databricks_bootcamp/bike_lakehouse/Silver/Silver_crm_sales_details",
  "/Workspace/Users/otilia.cecilia.lungu@gmail.com/databricks_bootcamp/bike_lakehouse/Silver/Silver_erp_cust_az12",
  "/Workspace/Users/otilia.cecilia.lungu@gmail.com/databricks_bootcamp/bike_lakehouse/Silver/Silver_erp_loc_a101",
  "/Workspace/Users/otilia.cecilia.lungu@gmail.com/databricks_bootcamp/bike_lakehouse/Silver/Silver_erp_px_cat_g1v2"
]
for nb in notebooks:
  print(f"Running {nb}")
  dbutils.notebook.run(nb, timeout_seconds = 0)
